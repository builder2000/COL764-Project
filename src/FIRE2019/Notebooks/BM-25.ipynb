# %%
import pandas as pd
import numpy as np
import string
import os
import sys
import re
from collections import Counter, defaultdict
from nltk import word_tokenize, RegexpTokenizer
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.stem import WordNetLemmatizer
from rank_bm25 import BM25Okapi
import itertools
ps = PorterStemmer()
lemmatizer = WordNetLemmatizer()

# %%
qrels = pd.read_csv("D:\\Courses\\Sem 7 2021-22\\COL764\\COL764 Project\\AILA_2019_dataset\\relevance_judgments_priorcases.txt", sep = ' ', header=None)

# %%
# is this stopword list the correct one ? can we try other stopword collections or may be custom ?
stopword_set = set(stopwords.words('english'))
def stopword_removal(word_list):

    return [word for word in word_list if word not in stopword_set ]    


# do we make the case lower for legal documents?
def tokenize_document(doc, lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
                      tokenizer = 'RegExpTokeinzer', lemmatize = True):
    
    # punctuations are removed with empty string
    doc = doc.translate(str.maketrans('', '', string.punctuation))
    
    # do we convert to lowercase?
    if(lowercase):
        doc = doc.lower()
    
    
    # variety of tokenizers could be experimented with
    if(tokenizer == 'RegExpTokeinzer'):
        tokenizer = RegexpTokenizer(r'\w+')
        tokens = tokenizer.tokenize(doc)
    
    # word tokenizer of nltk - a bit slow since based on NLP techniques
    elif(tokenizer == 'Word_tokenizer'):
        tokens = word_tokenize(doc)
    
        
    if(removeStopwords == True):
        tokens = stopword_removal(tokens)
    
        
    #variety of stemmers could be experimented with
    if(stemming):
        if(stemmer == 'PorterStemmer'):
            tokens = [ps.stem(token) for token in tokens ]
        
    
    # We can also perform lemmatization if we want
    # write function for lemmatizer here.
    if(lemmatize == True):
        tokens = [lemmatizer.lemmatize(token) for token in tokens]
    
    
    return tokens

# %%
# this function is for processing the corpus
def process_corpus(filename, lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
                    tokenizer = 'RegExpTokeinzer'):
    corpus_files = os.listdir(filename)
    
    list_tokens = []
    
    indexes_of_doc = defaultdict(lambda:0)
    
    count = 0
    for corpus_file in corpus_files:
        filepath = os.path.join(filename, corpus_file)
        
        indexes_of_doc[count] = corpus_file[:-4]
        print(corpus_file)
        with open(filepath, 'r') as f:
            doc_text = f.readlines()
            
            
            doc_text = ''.join(doc_text)
            
            # this considers all words
            tokens = tokenize_document(doc_text, lowercase = lowercase, removeStopwords = removeStopwords , stemming = stemming, 
                                       stemmer = stemmer , tokenizer =  tokenizer)
            
            list_tokens.append(tokens)
        
        count +=1
    
    return list_tokens, indexes_of_doc

# %%
list_tokens, indexes_of_doc = process_corpus("D:\Courses\Sem 7 2021-22\COL764\COL764 Project\AILA_2019_dataset\Object_casedocs", lowercase = True, stemming = True)
# Out:
# C1.txt
# C10.txt
# C100.txt
# C1000.txt
# C1001.txt
# C1002.txt
# C1003.txt
# C1004.txt
# C1005.txt
# C1006.txt
# C1007.txt
# C1008.txt
# C1009.txt
# C101.txt
# C1010.txt
# C1011.txt
# C1012.txt
# C1013.txt
# C1014.txt
# C1015.txt
# C1016.txt
# C1017.txt
# C1018.txt
# C1019.txt
# C102.txt
# C1020.txt
# C1021.txt
# C1022.txt
# C1023.txt
# C1024.txt
# C1025.txt
# C1026.txt
# C1027.txt
# C1028.txt
# C1029.txt
# C103.txt
# C1030.txt
# C1031.txt
# C1032.txt
# C1033.txt
# C1034.txt
# C1035.txt
# C1036.txt
# C1037.txt
# C1038.txt
# C1039.txt
# C104.txt
# C1040.txt
# C1041.txt
# C1042.txt
# C1043.txt
# C1044.txt
# C1045.txt
# C1046.txt
# C1047.txt
# C1048.txt
# C1049.txt
# C105.txt
# C1050.txt
# C1051.txt
# C1052.txt
# C1053.txt
# C1054.txt
# C1055.txt
# C1056.txt
# C1057.txt
# C1058.txt
# C1059.txt
# C106.txt
# C1060.txt
# C1061.txt
# C1062.txt
# C1063.txt
# C1064.txt
# C1065.txt
# C1066.txt
# C1067.txt
# C1068.txt
# C1069.txt
# C107.txt
# C1070.txt
# C1071.txt
# C1072.txt
# C1073.txt
# C1074.txt
# C1075.txt
# C1076.txt
# C1077.txt
# C1078.txt
# C1079.txt
# C108.txt
# C1080.txt
# C1081.txt
# C1082.txt
# C1083.txt
# C1084.txt
# C1085.txt
# C1086.txt
# C1087.txt
# C1088.txt
# C1089.txt
# C109.txt
# C1090.txt
# C1091.txt
# C1092.txt
# C1093.txt
# C1094.txt
# C1095.txt
# C1096.txt
# C1097.txt
# C1098.txt
# C1099.txt
# C11.txt
# C110.txt
# C1100.txt
# C1101.txt
# C1102.txt
# C1103.txt
# C1104.txt
# C1105.txt
# C1106.txt
# C1107.txt
# C1108.txt
# C1109.txt
# C111.txt
# C1110.txt
# C1111.txt
# C1112.txt
# C1113.txt
# C1114.txt
# C1115.txt
# C1116.txt
# C1117.txt
# C1118.txt
# C1119.txt
# C112.txt
# C1120.txt
# C1121.txt
# C1122.txt
# C1123.txt
# C1124.txt
# C1125.txt
# C1126.txt
# C1127.txt
# C1128.txt
# C1129.txt
# C113.txt
# C1130.txt
# C1131.txt
# C1132.txt
# C1133.txt
# C1134.txt
# C1135.txt
# C1136.txt
# C1137.txt
# C1138.txt
# C1139.txt
# C114.txt
# C1140.txt
# C1141.txt
# C1142.txt
# C1143.txt
# C1144.txt
# C1145.txt
# C1146.txt
# C1147.txt
# C1148.txt
# C1149.txt
# C115.txt
# C1150.txt
# C1151.txt
# C1152.txt
# C1153.txt
# C1154.txt
# C1155.txt
# C1156.txt
# C1157.txt
# C1158.txt
# C1159.txt
# C116.txt
# C1160.txt
# C1161.txt
# C1162.txt
# C1163.txt
# C1164.txt
# C1165.txt
# C1166.txt
# C1167.txt
# C1168.txt
# C1169.txt
# C117.txt
# C1170.txt
# C1171.txt
# C1172.txt
# C1173.txt
# C1174.txt
# C1175.txt
# C1176.txt
# C1177.txt
# C1178.txt
# C1179.txt
# C118.txt
# C1180.txt
# C1181.txt
# C1182.txt
# C1183.txt
# C1184.txt
# C1185.txt
# C1186.txt
# C1187.txt
# C1188.txt
# C1189.txt
# C119.txt
# C1190.txt
# C1191.txt
# C1192.txt
# C1193.txt
# C1194.txt
# C1195.txt
# C1196.txt
# C1197.txt
# C1198.txt
# C1199.txt
# C12.txt
# C487.txt
# C488.txt
# C489.txt
# C49.txt
# C490.txt
# C491.txt
# C492.txt
# C493.txt
# C494.txt
# C495.txt
# C496.txt
# C497.txt
# C498.txt
# C499.txt
# C5.txt
# C50.txt
# C500.txt
# C501.txt
# C502.txt
# C503.txt
# C504.txt
# C505.txt
# C506.txt
# C507.txt
# C508.txt
# C509.txt
# C51.txt
# C510.txt
# C511.txt
# C512.txt
# C513.txt
# C514.txt
# C515.txt
# C516.txt
# C517.txt
# C518.txt
# C519.txt
# C52.txt
# C520.txt
# C521.txt
# C522.txt
# C523.txt
# C524.txt
# C525.txt
# C526.txt
# C527.txt
# C528.txt
# C529.txt
# C53.txt
# C530.txt
# C531.txt
# C532.txt
# C533.txt
# C534.txt
# C535.txt
# C536.txt
# C537.txt
# C538.txt
# C539.txt
# C54.txt
# C540.txt
# C541.txt
# C542.txt
# C543.txt
# C544.txt
# C545.txt
# C546.txt
# C547.txt
# C548.txt
# C549.txt
# C55.txt
# C550.txt
# C551.txt
# C552.txt
# C553.txt
# C554.txt
# C555.txt
# C556.txt
# C557.txt
# C558.txt
# C559.txt
# C56.txt
# C560.txt
# C561.txt
# C562.txt
# C563.txt
# C564.txt
# C565.txt
# C566.txt
# C567.txt
# C568.txt
# C569.txt
# C57.txt
# C570.txt
# C571.txt
# C572.txt
# C573.txt
# C574.txt
# C575.txt
# C576.txt
# C577.txt
# C578.txt
# C579.txt
# C58.txt
# C580.txt
# C581.txt
# C582.txt
# C583.txt
# C584.txt
# C585.txt
# C586.txt
# C587.txt
# C588.txt
# C589.txt
# C59.txt
# C590.txt
# C591.txt
# C592.txt
# C593.txt
# C594.txt
# C595.txt
# C596.txt
# C597.txt
# C598.txt
# C599.txt
# C6.txt
# C60.txt
# C600.txt
# C601.txt
# C602.txt
# C603.txt
# C604.txt
# C605.txt
# C606.txt
# C607.txt
# C608.txt
# C609.txt
# C61.txt
# C610.txt
# C611.txt
# C612.txt
# C613.txt
# C614.txt
# C615.txt
# C616.txt
# C617.txt
# C618.txt
# C619.txt
# C62.txt
# C620.txt
# C621.txt
# C622.txt
# C623.txt
# C624.txt
# C625.txt
# C626.txt
# C627.txt
# C628.txt
# C629.txt
# C63.txt
# C630.txt
# C631.txt
# C632.txt
# C633.txt
# C634.txt
# C635.txt
# C636.txt
# C637.txt
# C638.txt
# C639.txt
# C64.txt
# C640.txt
# C641.txt
# C642.txt
# C643.txt
# C644.txt
# C645.txt
# C646.txt
# C647.txt
# C648.txt
# C649.txt
# C65.txt
# C650.txt
# C651.txt
# C652.txt
# C653.txt
# C654.txt
# C655.txt
# C656.txt
# C657.txt
# C658.txt
# C659.txt
# C66.txt
# C660.txt
# C661.txt
# C662.txt
# C663.txt
# C664.txt
# C665.txt
# C666.txt
# C667.txt
# C668.txt
# C669.txt
# C67.txt
# C670.txt
# C671.txt
# C672.txt
# C673.txt
# C674.txt
# C675.txt
# C676.txt
# C677.txt
# C678.txt
# C679.txt
# C68.txt
# C680.txt
# C681.txt
# C682.txt
# C683.txt
# C684.txt
# C685.txt
# C686.txt
# C687.txt
# C688.txt
# C689.txt
# C69.txt
# C690.txt
# C691.txt
# C692.txt
# C693.txt
# C694.txt
# C695.txt
# C696.txt
# C697.txt
# C698.txt
# C699.txt
# C7.txt
# C70.txt
# C700.txt
# C701.txt
# C702.txt
# C703.txt
# C704.txt
# C705.txt
# C706.txt
# C707.txt
# C708.txt
# C709.txt
# C71.txt
# C710.txt
# C711.txt
# C712.txt
# C713.txt
# C714.txt
# C715.txt
# C716.txt
# C717.txt
# C718.txt
# C719.txt
# C72.txt
# C720.txt
# C721.txt
# C722.txt
# C723.txt
# C724.txt
# C725.txt
# C726.txt
# C727.txt
# C728.txt
# C729.txt
# C73.txt
# C730.txt
# C731.txt
# C732.txt
# C733.txt
# C734.txt
# C735.txt
# C736.txt
# C737.txt
# C738.txt
# C739.txt
# C74.txt
# C740.txt
# C741.txt
# C742.txt
# C743.txt
# C744.txt
# C745.txt
# C746.txt
# C747.txt
# C748.txt
# C749.txt
# C75.txt
# C750.txt
# C751.txt
# C752.txt
# C753.txt
# C754.txt
# C755.txt
# C756.txt
# C757.txt
# C758.txt
# C759.txt
# C76.txt
# C760.txt
# C761.txt
# C762.txt
# C763.txt
# C764.txt
# C765.txt
# C766.txt
# C767.txt
# C768.txt
# C769.txt
# C77.txt
# C770.txt
# C771.txt
# C772.txt
# C773.txt
# C774.txt
# C775.txt
# C776.txt
# C777.txt
# C778.txt
# C779.txt
# C78.txt
# C780.txt
# C781.txt
# C782.txt
# C783.txt
# C784.txt
# C785.txt
# C786.txt
# C787.txt
# C788.txt
# C789.txt
# C79.txt
# C790.txt
# C791.txt
# C792.txt
# C793.txt
# C794.txt
# C795.txt
# C796.txt
# C797.txt
# C798.txt
# C799.txt
# C8.txt
# C80.txt
# C800.txt
# C801.txt
# C802.txt
# C803.txt
# C804.txt
# C805.txt
# C806.txt
# C807.txt
# C808.txt
# C809.txt
# C81.txt
# C810.txt
# C811.txt
# C812.txt
# C813.txt
# C814.txt
# C815.txt
# C816.txt
# C817.txt
# C818.txt
# C819.txt
# C82.txt
# C820.txt
# C821.txt
# C822.txt
# C823.txt
# C824.txt
# C825.txt
# C826.txt
# C827.txt
# C828.txt
# C829.txt
# C83.txt
# C830.txt
# C831.txt
# C832.txt
# C833.txt
# C834.txt
# C835.txt
# C836.txt
# C837.txt
# C838.txt
# C839.txt
# C84.txt
# C840.txt
# C841.txt
# C842.txt
# C843.txt
# C844.txt
# C845.txt
# C846.txt
# C847.txt
# C848.txt
# C849.txt
# C85.txt
# C850.txt
# C851.txt
# C852.txt
# C853.txt
# C854.txt
# C855.txt
# C856.txt
# C857.txt
# C858.txt
# C859.txt
# C86.txt
# C860.txt
# C861.txt
# C862.txt
# C863.txt
# C864.txt
# C865.txt
# C866.txt
# C867.txt
# C868.txt
# C869.txt
# C87.txt
# C870.txt
# C871.txt
# C872.txt
# C873.txt
# C874.txt
# C875.txt
# C876.txt
# C877.txt
# C878.txt
# C879.txt
# C88.txt
# C880.txt
# C881.txt
# C882.txt
# C883.txt
# C884.txt
# C885.txt
# C886.txt
# C887.txt
# C888.txt
# C889.txt
# C89.txt
# C890.txt
# C891.txt
# C892.txt
# C893.txt
# C894.txt
# C895.txt
# C896.txt
# C897.txt
# C898.txt
# C899.txt
# C9.txt
# C90.txt
# C900.txt
# C901.txt
# C902.txt
# C903.txt
# C904.txt
# C905.txt
# C906.txt
# C907.txt
# C908.txt
# C909.txt
# C91.txt
# C910.txt
# C911.txt
# C912.txt
# C913.txt
# C914.txt
# C915.txt
# C916.txt
# C917.txt
# C918.txt
# C919.txt
# C92.txt
# C920.txt
# C921.txt
# C922.txt
# C923.txt
# C924.txt
# C925.txt
# C926.txt
# C927.txt
# C928.txt
# C929.txt
# C93.txt
# C930.txt
# C931.txt
# C932.txt
# C933.txt
# C934.txt
# C935.txt
# C936.txt
# C937.txt
# C938.txt
# C939.txt
# C94.txt
# C940.txt
# C941.txt
# C942.txt
# C943.txt
# C944.txt
# C945.txt
# C946.txt
# C947.txt
# C948.txt
# C949.txt
# C95.txt
# C950.txt
# C951.txt
# C952.txt
# C953.txt
# C954.txt
# C955.txt
# C956.txt
# C957.txt
# C958.txt
# C959.txt
# C96.txt
# C960.txt
# C961.txt
# C962.txt
# C963.txt
# C964.txt
# C965.txt
# C966.txt
# C967.txt
# C968.txt
# C969.txt
# C97.txt
# C970.txt
# C971.txt
# C972.txt
# C973.txt
# C974.txt
# C975.txt
# C976.txt
# C977.txt
# C978.txt
# C979.txt
# C98.txt
# C980.txt
# C981.txt
# C982.txt
# C983.txt
# C984.txt
# C985.txt
# C986.txt
# C987.txt
# C988.txt
# C989.txt
# C99.txt
# C990.txt
# C991.txt
# C992.txt
# C993.txt
# C994.txt
# C995.txt
# C996.txt
# C997.txt
# C998.txt
# C999.txt

# %%
def process_full_queries(filename):
    with open(filename, 'r') as f:
        doc_text = f.readlines() 
        doc_text = ''.join(doc_text)
        
    indexes = [x.start() for x in re.finditer('\|\|', doc_text)]
    
    print(len(indexes))
    
    queries = defaultdict(lambda: '')
    for i in range(len(indexes)):
        if(i == len(indexes) -1):
            queries['AILA_' + "Q" + str(i+1)] = doc_text[indexes[i] + 2:]
            
        else:
            queries['AILA_' + "Q" + str(i+1)] = doc_text[indexes[i] + 2: indexes[i+1] -1 - 7]

    print(indexes)
    
    return queries

# %%
queries = process_full_queries("D:\Courses\Sem 7 2021-22\COL764\COL764 Project\AILA_2019_dataset\Query_doc.txt")
# Out:
# 50
# [7, 5765, 8632, 9816, 12030, 15965, 18270, 19678, 22954, 26658, 28621, 33438, 34699, 37938, 40233, 43301, 46499, 49910, 51589, 55219, 57636, 60119, 64479, 68500, 73619, 76442, 82389, 85445, 86922, 91390, 95040, 98250, 99709, 102699, 107656, 112130, 116100, 119180, 120851, 125122, 126946, 130526, 131935, 134481, 136778, 138521, 141979, 146028, 147703, 149210]

# %%
def bm25_query(queries, queryname, bm25, lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
               tokenizer = 'RegExpTokeinzer'):
    
    query_scores_doc = defaultdict(lambda:0)
    
    query = queries[queryname]

    query_tokens = tokenize_document(query, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, 
                                         stemmer = stemmer, tokenizer = tokenizer)
        

    doc_scores = bm25.get_scores(query_tokens)
        
        # top 100 queries for each doc
    indices = np.argsort(doc_scores)[::-1]
        
    values = [doc_scores[i] for i in indices]
        
        
    for i in range(len(indices)):
        index = indices[i]
        score = values[i]
            
        query_scores_doc[index] = query_scores_doc[index]  if query_scores_doc[index] > score else score

     
    results = sorted(query_scores_doc.items(), key = lambda x: x[1], reverse = True)
    
    
    rankings = []
    
    for result in results:
        index = result[0]
        rankings.append(indexes_of_doc[index])

    return rankings

# %%
# 2nd model (filtering out with idf)
def bm25_query_idf(queries, queryname, bm25, lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
               tokenizer = 'RegExpTokeinzer'):
    
    query_scores_doc = defaultdict(lambda:0)
    
    query = queries[queryname]

    query_tokens = tokenize_document(query, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, 
                                         stemmer = stemmer, tokenizer = tokenizer)
    
   
    query_tokens = tokenize_document(query, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, 
                                         stemmer = stemmer, tokenizer = tokenizer)
    
    full_doc_scores = bm25.get_scores(query_tokens)
    
    
    filtered_query = sorted(query_tokens, key = lambda x : bm25.idf[x] if x in bm25.idf else 0, reverse = True)
                

    # selecting top 50 % terms
    query_tokens = filtered_query[0: len(filtered_query)//2]
        
    idf_doc_scores = bm25.get_scores(query_tokens)
    

    doc_scores = [full_doc_scores[i] + idf_doc_scores[i] for i in range(len(full_doc_scores))]

    indices = np.argsort(doc_scores)[::-1]
        
    values = [doc_scores[i] for i in indices]         
        
    for i in range(len(indices)):
        index = indices[i]
        score = values[i]
            
        query_scores_doc[index] = query_scores_doc[index]  if query_scores_doc[index] > score else score

     
    results = sorted(query_scores_doc.items(), key = lambda x: x[1], reverse = True)
    
    
    rankings = []
    
    for result in results:
        index = result[0]
        rankings.append(indexes_of_doc[index])
        
        
    
    return rankings

# %%
def AP(qrel, rankings, queryname):
    relevant_docs = qrels[qrels[0] == queryname][qrels[3] == 1][2].values
    
    
    relevant_docs_retrieved = 0
    
    precision = []
    for i in range(len(rankings)):
        doc = rankings[i]
        docs_retrieved = i + 1
        
        if doc in relevant_docs:
            relevant_docs_retrieved +=1
            
            precision.append(relevant_docs_retrieved/docs_retrieved)
            
    
    if(len(precision) == 0):
        return 0, 0
        
    
    return np.sum(precision)/len(relevant_docs), len(precision)


def MRR(qrel,  rankings, queryname):
    relevant_docs = qrels[qrels[0] == queryname][qrels[3] == 1][2].values
    
    rec = 0
    for i in range(len(rankings)):
        doc = rankings[i]
        if doc in relevant_docs:
            return 1/(i+1)
    
    return rec

def P_at_10(qrel,  rankings, queryname):
    relevant_docs = qrels[qrels[0] == queryname][qrels[3] == 1][2].values
    
    relevant = 0
    for i in range(10):
        doc = rankings[i]
        if doc in relevant_docs:
            relevant +=1
    
    return relevant/10

def Rec_at_100(qrel,  rankings, queryname):
    relevant_docs = qrels[qrels[0] == queryname][2].values
    
    relevant = 0
    for i in range(100):
        doc = rankings[i]
        if doc in relevant_docs:
            relevant +=1
    
    return relevant/len(relevant_docs)

# %%
def obtain_relevant_docs(queries, bm25, lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
                      tokenizer = 'RegExpTokeinzer', model = 1):
    
    querynames = queries.keys()
    
    
    list_AP = []
    list_MRR = []
    list_P10 = []
    list_Rec100 = []
    for queryname in querynames:
        if(model == 1):
            rankings = bm25_query(queries, queryname, bm25, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, stemmer = stemmer,
                              tokenizer = tokenizer)[:100]
        elif(model == 2):
            rankings = bm25_query_idf(queries, queryname, bm25, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, stemmer = stemmer,
                              tokenizer = tokenizer)[:100]
        
        ap = AP(qrels, rankings, queryname)
        
        mrr = MRR(qrels, rankings, queryname)
        
        p10 = P_at_10(qrels, rankings, queryname)
        
        rec100 = Rec_at_100(qrels,  rankings, queryname)
        
        print(queryname, ap, mrr, p10)
        
        list_AP.append(ap[0])
        list_MRR.append(mrr)
        list_P10.append(p10)
        list_Rec100.append(rec100)
        
    return np.mean(list_AP), np.mean(list_MRR) , np.mean(list_P10), np.mean(list_Rec100)

# %%
def tune_hyperparameters(lowercase = False, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
                      tokenizer = 'RegExpTokeinzer', model = 1):
    k1_list = np.linspace(1, 2, 5)
    b_list = np.linspace(0.70, 1, 6)
    
    parameter_list = [k1_list, b_list]
    hyperparameters = list(itertools.product(*parameter_list))
    
    MAP_list = defaultdict(lambda:0)
    for x in hyperparameters:
        print(x)
        bm25 = BM25Okapi(list_tokens, k1= x[0], b= x[1])
        
        map, mrr, p10, rec100 = obtain_relevant_docs(queries, bm25, lowercase = lowercase, removeStopwords = removeStopwords, stemming = stemming, stemmer = stemmer,
                              tokenizer = tokenizer, model = model)
        
        MAP_list[x] = map
        print("MAP is:", map)
        print("MRR is:", mrr)
        print("MRR is:", p10)
        print("Rec100 is:", rec100)
    return MAP_list

# %%
tune_hyperparameters(lowercase = True, removeStopwords = True, stemming = False, stemmer = 'PorterStemmer',
                      tokenizer = 'RegExpTokeinzer', model = 1)

# %%
bm25 = BM25Okapi(list_tokens, k1= 1.2, b= 0.75)       
map, mrr, p10, rec100 = obtain_relevant_docs(queries, bm25, lowercase = True, model = 1, stemming = True)
# Out:
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# AILA_Q1 (0.03125, 1) 0.0625 0.0
# AILA_Q2 (0, 0) 0 0.0
# AILA_Q3 (0, 0) 0 0.0
# AILA_Q4 (0, 0) 0 0.0
# AILA_Q5 (0, 0) 0 0.0
# AILA_Q6 (0, 0) 0 0.0
# AILA_Q7 (0, 0) 0 0.0
# AILA_Q8 (0, 0) 0 0.0
# AILA_Q9 (0, 0) 0 0.0
# AILA_Q10 (0.014141414141414142, 2) 0.022222222222222223 0.0
# AILA_Q11 (0.043478260869565216, 2) 0.043478260869565216 0.0
# AILA_Q12 (0, 0) 0 0.0
# AILA_Q13 (0.05555555555555555, 1) 0.16666666666666666 0.1
# AILA_Q14 (1.0, 1) 1.0 0.1
# AILA_Q15 (0, 0) 0 0.0
# AILA_Q16 (0, 0) 0 0.0
# AILA_Q17 (0.014756135445790618, 2) 0.017241379310344827 0.0
# AILA_Q18 (1.0, 1) 1.0 0.1
# AILA_Q19 (0.003676470588235294, 1) 0.014705882352941176 0.0
# AILA_Q20 (0, 0) 0 0.0
# AILA_Q21 (0.2916666666666667, 2) 1.0 0.1
# AILA_Q22 (0, 0) 0 0.0
# AILA_Q23 (0, 0) 0 0.0
# AILA_Q24 (0, 0) 0 0.0
# AILA_Q25 (0.023809523809523808, 1) 0.14285714285714285 0.1
# AILA_Q26 (0.031746031746031744, 2) 0.14285714285714285 0.1
# AILA_Q27 (0.14075518167133075, 5) 0.3333333333333333 0.1
# AILA_Q28 (0, 0) 0 0.0
# AILA_Q29 (0.055816811734364924, 5) 1.0 0.1
# AILA_Q30 (0.009808612440191388, 2) 0.05263157894736842 0.0
# AILA_Q31 (0.25, 1) 0.5 0.1
# AILA_Q32 (0, 0) 0 0.0
# AILA_Q33 (1.0, 1) 1.0 0.1
# AILA_Q34 (0.04720279720279719, 3) 0.3333333333333333 0.2
# AILA_Q35 (0, 0) 0 0.0
# AILA_Q36 (0.5096618357487922, 4) 1.0 0.3
# AILA_Q37 (0, 0) 0 0.0
# AILA_Q38 (0.004347826086956522, 1) 0.021739130434782608 0.0
# AILA_Q39 (0.038911887262739635, 7) 0.07142857142857142 0.0
# AILA_Q40 (0, 0) 0 0.0
# AILA_Q41 (0, 0) 0 0.0
# AILA_Q42 (0.009615384615384616, 1) 0.038461538461538464 0.0
# AILA_Q43 (0.030303030303030304, 1) 0.09090909090909091 0.0
# AILA_Q44 (0.06943625246071503, 5) 0.2 0.1
# AILA_Q45 (0.005319148936170213, 1) 0.010638297872340425 0.0
# AILA_Q46 (0.1527777777777778, 3) 0.5 0.3
# AILA_Q47 (0, 0) 0 0.0
# AILA_Q48 (0.75, 3) 1.0 0.3
# AILA_Q49 (0.022727272727272728, 1) 0.09090909090909091 0.0
# AILA_Q50 (0, 0) 0 0.0

# %%
map, mrr, p10, rec100
# Out:
# (0.11213527755580614,
#  0.19711825325530952,
#  0.044000000000000004,
#  0.03431708991077557)

# %%
bm25 = BM25Okapi(list_tokens, k1= 1.2, b= 0.75)       
map, mrr, p10, rec100 = obtain_relevant_docs(queries, bm25, lowercase = True, stemming = True, model = 2)
# Out:
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:26: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# C:\Users\Rohan Debbarma\Anaconda3\lib\site-packages\ipykernel_launcher.py:37: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# AILA_Q1 (0.07142857142857142, 1) 0.07142857142857142 0.0
# AILA_Q2 (0, 0) 0 0.0
# AILA_Q3 (0, 0) 0 0.0
# AILA_Q4 (0, 0) 0 0.0
# AILA_Q5 (0, 0) 0 0.0
# AILA_Q6 (0, 0) 0 0.0
# AILA_Q7 (0, 0) 0 0.0
# AILA_Q8 (0, 0) 0 0.0
# AILA_Q9 (0.0125, 1) 0.0125 0.0
# AILA_Q10 (0.012987012987012988, 1) 0.012987012987012988 0.0
# AILA_Q11 (0.046536796536796536, 2) 0.045454545454545456 0.0
# AILA_Q12 (0, 0) 0 0.0
# AILA_Q13 (0.16666666666666666, 1) 0.16666666666666666 0.1
# AILA_Q14 (1.0, 1) 1.0 0.1
# AILA_Q15 (0, 0) 0 0.0
# AILA_Q16 (0, 0) 0 0.0
# AILA_Q17 (0.029795503250880827, 3) 0.017543859649122806 0.0
# AILA_Q18 (1.0, 1) 1.0 0.1
# AILA_Q19 (0.0125, 1) 0.0125 0.0
# AILA_Q20 (0, 0) 0 0.0
# AILA_Q21 (0.5833333333333334, 2) 1.0 0.1
# AILA_Q22 (0, 0) 0 0.0
# AILA_Q23 (0, 0) 0 0.0
# AILA_Q24 (0, 0) 0 0.0
# AILA_Q25 (0.14285714285714285, 1) 0.14285714285714285 0.1
# AILA_Q26 (0.08258258258258258, 2) 0.1111111111111111 0.1
# AILA_Q27 (0.2824720068906115, 5) 1.0 0.1
# AILA_Q28 (0, 0) 0 0.0
# AILA_Q29 (0.29653289653289655, 4) 1.0 0.1
# AILA_Q30 (0.05165816326530612, 2) 0.0625 0.0
# AILA_Q31 (1.0, 1) 1.0 0.1
# AILA_Q32 (0, 0) 0 0.0
# AILA_Q33 (0.5, 1) 0.5 0.1
# AILA_Q34 (0.18692528735632186, 4) 0.25 0.2
# AILA_Q35 (0, 0) 0 0.0
# AILA_Q36 (0.6202020202020202, 5) 1.0 0.3
# AILA_Q37 (0, 0) 0 0.0
# AILA_Q38 (0.018518518518518517, 1) 0.018518518518518517 0.0
# AILA_Q39 (0.08293545481433681, 7) 0.14285714285714285 0.1
# AILA_Q40 (0, 0) 0 0.0
# AILA_Q41 (0, 0) 0 0.0
# AILA_Q42 (0.03225806451612903, 1) 0.03225806451612903 0.0
# AILA_Q43 (0.09090909090909091, 1) 0.09090909090909091 0.0
# AILA_Q44 (0.05080237223094366, 3) 0.08333333333333333 0.0
# AILA_Q45 (0, 0) 0 0.0
# AILA_Q46 (0.30208333333333337, 4) 0.3333333333333333 0.3
# AILA_Q47 (0, 0) 0 0.0
# AILA_Q48 (1.0, 3) 1.0 0.3
# AILA_Q49 (0.047619047619047616, 1) 0.047619047619047616 0.0
# AILA_Q50 (0, 0) 0 0.0

# %%
map, mrr, p10, rec100
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-64c75455bc73> in <module>
# ----> 1 map, mrr, p10, rec100
#
# NameError: name 'mrr' is not defined
